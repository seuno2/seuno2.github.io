# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/DontGetKicked/example_entry.csv
# /kaggle/input/DontGetKicked/training.zip
# /kaggle/input/DontGetKicked/Carvana_Data_Dictionary.txt
# /kaggle/input/DontGetKicked/test.zip
# /kaggle/input/DontGetKicked/training.csv
# /kaggle/input/DontGetKicked/test.csv

# %% [markdown]
# # Introductory Summary
#
# 1. Rank 16th / 570 (Late submission)
#
# 2. Feature Engineering of DateTime Variables
#
# 3. Replacing NaN with Zero
#
# 4. Label Encoding for Categorical Features

# %%
train = pd.read_csv('/kaggle/input/DontGetKicked/training.csv')
test = pd.read_csv('/kaggle/input/DontGetKicked/test.zip')

# %%
train
# Out:
#        RefId  IsBadBuy  PurchDate Auction  VehYear  VehicleAge       Make  \
# 0          1         0  12/7/2009   ADESA     2006           3      MAZDA
# 1          2         0  12/7/2009   ADESA     2004           5      DODGE
# 2          3         0  12/7/2009   ADESA     2005           4      DODGE
# 3          4         0  12/7/2009   ADESA     2004           5      DODGE
# 4          5         0  12/7/2009   ADESA     2005           4       FORD
# ...      ...       ...        ...     ...      ...         ...        ...
# 72978  73010         1  12/2/2009   ADESA     2001           8    MERCURY
# 72979  73011         0  12/2/2009   ADESA     2007           2  CHEVROLET
# 72980  73012         0  12/2/2009   ADESA     2005           4       JEEP
# 72981  73013         0  12/2/2009   ADESA     2006           3  CHEVROLET
# 72982  73014         0  12/2/2009   ADESA     2006           3      MAZDA
#
#                       Model Trim           SubModel  ...  \
# 0                    MAZDA3    i         4D SEDAN I  ...
# 1       1500 RAM PICKUP 2WD   ST  QUAD CAB 4.7L SLT  ...
# 2                STRATUS V6  SXT   4D SEDAN SXT FFV  ...
# 3                      NEON  SXT           4D SEDAN  ...
# 4                     FOCUS  ZX3       2D COUPE ZX3  ...
# ...                     ...  ...                ...  ...
# 72978                 SABLE   GS        4D SEDAN GS  ...
# 72979             MALIBU 4C   LS        4D SEDAN LS  ...
# 72980  GRAND CHEROKEE 2WD V  Lar    4D WAGON LAREDO  ...
# 72981                IMPALA   LS        4D SEDAN LS  ...
# 72982                MAZDA6    s         4D SEDAN S  ...
#
#       MMRCurrentRetailAveragePrice MMRCurrentRetailCleanPrice  PRIMEUNIT  \
# 0                          11597.0                    12409.0        NaN
# 1                          11374.0                    12791.0        NaN
# 2                           7146.0                     8702.0        NaN
# 3                           4375.0                     5518.0        NaN
# 4                           6739.0                     7911.0        NaN
# ...                            ...                        ...        ...
# 72978                       4836.0                     5937.0        NaN
# 72979                      10151.0                    11652.0        NaN
# 72980                      11831.0                    14402.0        NaN
# 72981                      10099.0                    11228.0        NaN
# 72982                      11954.0                    13246.0        NaN
#
#       AUCGUART  BYRNO VNZIP1 VNST VehBCost  IsOnlineSale  WarrantyCost
# 0          NaN  21973  33619   FL   7100.0             0          1113
# 1          NaN  19638  33619   FL   7600.0             0          1053
# 2          NaN  19638  33619   FL   4900.0             0          1389
# 3          NaN  19638  33619   FL   4100.0             0           630
# 4          NaN  19638  33619   FL   4000.0             0          1020
# ...        ...    ...    ...  ...      ...           ...           ...
# 72978      NaN  18111  30212   GA   4200.0             0           993
# 72979      NaN  18881  30212   GA   6200.0             0          1038
# 72980      NaN  18111  30212   GA   8200.0             0          1893
# 72981      NaN  18881  30212   GA   7000.0             0          1974
# 72982      NaN  18111  30212   GA   8000.0             0          1313
#
# [72983 rows x 34 columns]

# %%
test
# Out:
#         RefId   PurchDate  Auction  VehYear  VehicleAge       Make  \
# 0       73015   12/2/2009    ADESA     2005           4    PONTIAC
# 1       73016   12/2/2009    ADESA     2005           4  CHEVROLET
# 2       73017   12/2/2009    ADESA     2006           3      DODGE
# 3       73018   12/2/2009    ADESA     2002           7     SATURN
# 4       73019   12/2/2009    ADESA     2007           2    HYUNDAI
# ...       ...         ...      ...      ...         ...        ...
# 48702  121742  11/17/2010  MANHEIM     2005           5       FORD
# 48703  121743  11/17/2010  MANHEIM     2007           3     TOYOTA
# 48704  121744  11/17/2010  MANHEIM     2006           4        KIA
# 48705  121745  11/17/2010  MANHEIM     2005           5      MAZDA
# 48706  121746  11/17/2010  MANHEIM     2003           7      BUICK
#
#                 Model Trim                SubModel   Color  ...  \
# 0          GRAND PRIX  Bas                4D SEDAN  SILVER  ...
# 1           MALIBU V6   LS             4D SEDAN LS  SILVER  ...
# 2      DURANGO 2WD V8  Adv  4D SUV 4.7L ADVENTURER  SILVER  ...
# 3            L SERIES  L20           4D SEDAN L200    GOLD  ...
# 4              ACCENT   GS             2D COUPE GS    BLUE  ...
# ...               ...  ...                     ...     ...  ...
# 48702    FIVE HUNDRED  SEL            4D SEDAN SEL   BLACK  ...
# 48703         COROLLA   CE             4D SEDAN CE   GREEN  ...
# 48704         SPECTRA   EX             4D SEDAN EX   BLACK  ...
# 48705          MAZDA3    s             4D SEDAN GT  SILVER  ...
# 48706  RENDEZVOUS AWD   CX               4D SUV CX    GOLD  ...
#
#       MMRCurrentRetailAveragePrice  MMRCurrentRetailCleanPrice PRIMEUNIT  \
# 0                           8557.0                      9752.0       NaN
# 1                           7562.0                      9296.0       NaN
# 2                          15340.0                     16512.0       NaN
# 3                           5725.0                      6398.0       NaN
# 4                           5914.0                      7350.0       NaN
# ...                            ...                         ...       ...
# 48702                       9764.0                     11395.0       NaN
# 48703                      10283.0                     11565.0       NaN
# 48704                       7871.0                      9490.0        NO
# 48705                       8576.0                      9937.0        NO
# 48706                       8266.0                      9388.0        NO
#
#        AUCGUART  BYRNO VNZIP1 VNST  VehBCost  IsOnlineSale  WarrantyCost
# 0           NaN  18881  30212   GA    6500.0             0          2152
# 1           NaN  18111  30212   GA    6300.0             0          1118
# 2           NaN  18111  30212   GA    9700.0             0          1215
# 3           NaN  18881  30212   GA    4150.0             0          1933
# 4           NaN  18111  30212   GA    4100.0             0           920
# ...         ...    ...    ...  ...       ...           ...           ...
# 48702       NaN  20928  33411   FL    7955.0             0          1633
# 48703       NaN  20928  33411   FL    7035.0             0           594
# 48704     GREEN  20928  33411   FL    6335.0             0           594
# 48705     GREEN  20928  33411   FL    8055.0             0          1038
# 48706     GREEN  20928  33411   FL    7755.0             0          5392
#
# [48707 rows x 33 columns]

# %%
alldata = pd.concat([train,test])

alldata['PurchDate'] = pd.to_datetime(alldata['PurchDate'])
alldata['Year'] = alldata['PurchDate'].dt.year
alldata['Month'] = alldata['PurchDate'].dt.month
alldata['Day'] = alldata['PurchDate'].dt.day

alldata2 = alldata.drop(columns = ['PurchDate','IsBadBuy','RefId'])

# %%
alldata2 = alldata2.fillna(0)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_cols = alldata2.columns[alldata2.dtypes == object]
for i in cat_cols:
    alldata2[i] = le.fit_transform(list(alldata2[i]))

# %%
train2 = alldata2[:len(train)]
test2 = alldata2[len(train):]

# %%
from catboost import CatBoostClassifier
cbc = CatBoostClassifier(verbose = 100)
cbc.fit(train2,train['IsBadBuy'])
result = cbc.predict_proba(test2)
# Out:
# Learning rate set to 0.064347
# 0:	learn: 0.6367842	total: 84.3ms	remaining: 1m 24s
# 100:	learn: 0.2929173	total: 2.02s	remaining: 18s
# 200:	learn: 0.2837950	total: 3.97s	remaining: 15.8s
# 300:	learn: 0.2754287	total: 5.89s	remaining: 13.7s
# 400:	learn: 0.2683758	total: 7.86s	remaining: 11.7s
# 500:	learn: 0.2620957	total: 9.77s	remaining: 9.73s
# 600:	learn: 0.2563358	total: 11.7s	remaining: 7.74s
# 700:	learn: 0.2509843	total: 14s	remaining: 5.99s
# 800:	learn: 0.2460486	total: 16s	remaining: 3.96s
# 900:	learn: 0.2411165	total: 17.9s	remaining: 1.96s
# 999:	learn: 0.2364138	total: 19.8s	remaining: 0us

# %%
sub = pd.read_csv('/kaggle/input/DontGetKicked/example_entry.csv')
sub['IsBadBuy'] = result[:,1]
sub.to_csv('sub.csv', index = 0)

# %%
# train = pd.read_csv('/kaggle/input/DontGetKicked/training.csv')
# test = pd.read_csv('/kaggle/input/DontGetKicked/test.zip')

# alldata = pd.concat([train,test])

# alldata['PurchDate'] = pd.to_datetime(alldata['PurchDate'])
# alldata['Year'] = alldata['PurchDate'].dt.year
# alldata['Month'] = alldata['PurchDate'].dt.month
# alldata['Day'] = alldata['PurchDate'].dt.day

# alldata2 = alldata.drop(columns = ['PurchDate','IsBadBuy','RefId'])
# alldata2 = alldata2.fillna(0)

# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# cat_cols = alldata2.columns[alldata2.dtypes == object]
# for i in cat_cols:
#     alldata2[i] = le.fit_transform(list(alldata2[i]))


# train2 = alldata2[:len(train)]
# test2 = alldata2[len(train):]

# from catboost import CatBoostClassifier
# cbc = CatBoostClassifier(verbose = 100)
# cbc.fit(train2,train['IsBadBuy'])
# result = cbc.predict_proba(test2)
# sub = pd.read_csv('/kaggle/input/DontGetKicked/example_entry.csv')
# sub['IsBadBuy'] = result[:,1]
# sub.to_csv('sub.csv', index = 0)

# %%
sub = pd.read_csv('/kaggle/input/DontGetKicked/example_entry.csv')
sub['IsBadBuy'] = result[:,1]
sub.to_csv('sub.csv', index = 0)

# %% [markdown]
# ## Feature Importance

# %%
pd.Series(cbc.feature_importances_,index = train2.columns).sort_values(ascending = False)
# Out:
# WheelTypeID                          8.639382
# VNZIP1                               6.073894
# VehBCost                             5.689453
# WheelType                            5.665378
# Month                                5.564246
# BYRNO                                5.442246
# VehOdo                               4.556845
# MMRCurrentAuctionAveragePrice        3.632494
# SubModel                             3.232207
# MMRCurrentRetailCleanPrice           3.132773
# Auction                              3.061604
# Model                                3.036745
# VehYear                              3.023424
# MMRCurrentRetailAveragePrice         3.016504
# VehicleAge                           2.983788
# Day                                  2.948150
# WarrantyCost                         2.907155
# MMRCurrentAuctionCleanPrice          2.895196
# MMRAcquisitionRetailAveragePrice     2.732071
# VNST                                 2.687489
# MMRAcquisitionAuctionAveragePrice    2.531796
# Trim                                 2.498670
# MMRAcquisitionAuctionCleanPrice      2.433728
# MMRAcquisitonRetailCleanPrice        1.836897
# Year                                 1.786962
# Make                                 1.598977
# PRIMEUNIT                            1.515129
# Color                                1.477209
# AUCGUART                             1.073257
# Size                                 1.021740
# TopThreeAmericanName                 0.600162
# Nationality                          0.359518
# Transmission                         0.226843
# IsOnlineSale                         0.118065
# dtype: float64

# %%
alldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121690 entries, 0 to 48706
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   RefId                              121690 non-null  int64
#  1   IsBadBuy                           72983 non-null   float64
#  2   PurchDate                          121690 non-null  datetime64[ns]
#  3   Auction                            121690 non-null  object
#  4   VehYear                            121690 non-null  int64
#  5   VehicleAge                         121690 non-null  int64
#  6   Make                               121690 non-null  object
#  7   Model                              121690 non-null  object
#  8   Trim                               117780 non-null  object
#  9   SubModel                           121677 non-null  object
#  10  Color                              121678 non-null  object
#  11  Transmission                       121678 non-null  object
#  12  WheelTypeID                        116333 non-null  float64
#  13  WheelType                          116328 non-null  object
#  14  VehOdo                             121690 non-null  int64
#  15  Nationality                        121678 non-null  object
#  16  Size                               121678 non-null  object
#  17  TopThreeAmericanName               121678 non-null  object
#  18  MMRAcquisitionAuctionAveragePrice  121662 non-null  float64
#  19  MMRAcquisitionAuctionCleanPrice    121662 non-null  float64
#  20  MMRAcquisitionRetailAveragePrice   121662 non-null  float64
#  21  MMRAcquisitonRetailCleanPrice      121662 non-null  float64
#  22  MMRCurrentAuctionAveragePrice      121232 non-null  float64
#  23  MMRCurrentAuctionCleanPrice        121232 non-null  float64
#  24  MMRCurrentRetailAveragePrice       121232 non-null  float64
#  25  MMRCurrentRetailCleanPrice         121232 non-null  float64
#  26  PRIMEUNIT                          5935 non-null    object
#  27  AUCGUART                           5935 non-null    object
#  28  BYRNO                              121690 non-null  int64
#  29  VNZIP1                             121690 non-null  int64
#  30  VNST                               121690 non-null  object
#  31  VehBCost                           121690 non-null  float64
#  32  IsOnlineSale                       121690 non-null  int64
#  33  WarrantyCost                       121690 non-null  int64
#  34  Year                               121690 non-null  int64
#  35  Month                              121690 non-null  int64
#  36  Day                                121690 non-null  int64
# dtypes: datetime64[ns](1), float64(11), int64(11), object(14)
# memory usage: 35.3+ MB
